# %%
from sqlalchemy import Column, Integer, Text, ForeignKey, create_engine
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import relationship, sessionmaker
from src.config.config import settings

# %%
class Chapter(Base):
    __tablename__ = 'chapter'
    id = Column(Integer, primary_key=True)
    name = Column(Text)
    grade_id = Column(Integer)
    subject_id = Column(Integer)
    problems = relationship('ProblemType', backref='chapter', lazy=True)

class ProblemType(Base):
    __tablename__ = 'problem_type'
    id = Column(Integer, primary_key=True)
    name = Column(Text),
    solution_steps = Column(Text),
    chapter_id = Column(Integer, ForeignKey('chapter.id'))
# Out:
# /tmp/ipykernel_2545265/4155795065.py:1: SAWarning: This declarative base already contains a class with the same class name and module name as __main__.Chapter, and will be replaced in the string-lookup table.
#   class Chapter(Base):
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 class Chapter(Base):
#       2     __tablename__ = 'chapter'
#       3     id = Column(Integer, primary_key=True)
#
# File ~/Projects/syvan_projects/exam_elt/.venv/lib/python3.11/site-packages/sqlalchemy/orm/decl_api.py:196, in DeclarativeMeta.__init__(cls, classname, bases, dict_, **kw)
#     193         cls._sa_registry = reg
#     195 if not cls.__dict__.get("__abstract__", False):
# --> 196     _as_declarative(reg, cls, dict_)
#     197 type.__init__(cls, classname, bases, dict_)
#
# ...

# %%
engine = create_engine("postgresql://postgres:3FGae34ggFIg@dica-server:54321/knowledge_base")
Session = sessionmaker(bind=engine)
session = Session()

# %%
chapters = session.query(Chapter).all()
for chapter in chapters:
    print(chapter.name)
# Out:
# Ôn Tập Và Bổ Túc Về Số Tự Nhiên
# Số Nguyên
# Phân Số
# Đoạn Thẳng
# Góc
